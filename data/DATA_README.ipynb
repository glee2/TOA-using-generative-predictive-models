# %%
import pandas as pd
import numpy as np
import os, csv, json

# %% [markdown]
# # v01

# %%
data_v01_dir = "v01/"

# %%
train_v01 = pd.read_csv(data_v01_dir + "train.csv")
test_v01 = pd.read_csv(data_v01_dir + "test.csv")

display(train_v01.head())
display(test_v01.head())
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             Abstract  \
# 0  methods and systems for transforming a volume ...
# 1  a gardening glove or the like designed to prev...
# 2  a hockey helmet for receiving a head of a wear...
# 3  a toilet and toilet system suitable for a boat...
# 4  a water valve assembly is disclosed for mounti...
#
#                                                Title          No patent_id  \
# 0        systems and methods for transformable suits  US06981282   6981282
# 1  gardening gloves with cushion insert to protec...  US06981283   6981283
# 2  hockey helmet comprising a lateral adjustment ...  US06981284   6981284
# 3                     toilet and method of operation  US06981285   6981285
# ...

# %%
del train_v01, test_v01
